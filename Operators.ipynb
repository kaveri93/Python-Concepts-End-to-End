# %%
# +,-,*,/,//,%,>,<,>=,<=,!=,and,or,**,pow

# %%
10 + 20 + 30 + 50
# Out:
# 110

# %%
a = 10
b = 20

print(a + b)
# Out:
# 30

# %%
10 - 20
# Out:
# -10

# %%
5 * 4
# Out:
# 20

# %%
# / -> division
# // -> floor division
# % -> Mod function

# %%
21 / 5
# Out:
# 4.2

# %%
21 // 5
# Out:
# 4

# %%
21 % 5
# Out:
# 1

# %%
83 / 4
# Out:
# 20.75

# %%
83 // 4
# Out:
# 20

# %%
83 % 4
# Out:
# 3

# %%
2 * 5
# Out:
# 10

# %%
3 ** 3
# Out:
# 27

# %%
3 * 3
# Out:
# 9

# %%
2 ** 5
# Out:
# 32

# %%
10 > 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
10 >= 11

# %%
# =
a = 20

# %%
# ==

10 == 10
# Out:
# True

# %%
10 == 9
# Out:
# False

# %%
10 >= 21
# Out:
# False

# %%
10 <= 18
# Out:
# True

# %%
32 <= 50
# Out:
# True

# %%
32 < 32
# Out:
# False

# %%
32 <= 32
# Out:
# True

# %%
10 != 20
# Out:
# True

# %%
10 > 20 or 10 < 18
# Out:
# True

# %%
15 >= 11 or 15 <= 21
# Out:
# True

# %%
10 > 20 and 10 < 18
# Out:
# False

# %% [markdown]
# **Regularly used Built_in_functions**

# %%
print(123)
# Out:
# 123

# %%
print(type(123))
# Out:
# <class 'int'>

# %%
print(id(a))
# Out:
# 11654984

# %%
import math # trying to open the math library (math box)

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
len(dir(math))
# Out:
# 66

# %%
math.factorial(5)
# Out:
# 120

# %%
math.factorial(5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2699731665.py in <cell line: 0>()
# ----> 1 math.factorial(5,6)
#
# TypeError: math.factorial() takes exactly one argument (2 given)

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32

# %%
pow(2,5,5)
# Out:
# 2

# %%
pow(2,5,5,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1490135624.py in <cell line: 0>()
# ----> 1 pow(2,5,5,7)
#
# TypeError: pow() takes at most 3 arguments (4 given)
